# %% [markdown]
# # 方法一：

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot([[0,0],[1,1]],linewidth=4)
plt.show()
# Out:
# <div id='bf48f469-56ae-4945-99b4-8331a3196c4d'></div>

# %% [markdown]
# 但是只能有一个。
#
# # 方法二：

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [9.5, 6]
plt.plot([[0,0],[1,1]],linewidth=4)
plt.show()
